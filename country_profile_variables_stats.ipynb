# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Dataset/country_profile_variables.csv")

# %%
df_sampled=df.sample(30,random_state=3)
df_sampled
# Out:
#                               country             Region Surface area (km2)  \
# 108                          Kiribati         Micronesia                726
# 73                      French Guiana       SouthAmerica              83534
# 15                            Bahrain        WesternAsia                771
# 187                           Somalia      EasternAfrica             637657
# 3                      American Samoa          Polynesia                199
# 40                               Chad       MiddleAfrica            1284000
# 31                           Bulgaria      EasternEurope             111002
# 173  Saint Vincent and the Grenadines          Caribbean                389
# 159                       Philippines  South-easternAsia             300000
# 58                           Djibouti      EasternAfrica              23200
# 185                          Slovenia     SouthernEurope              20273
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 50 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   country                                                     229 non-null    object
#  1   Region                                                      229 non-null    object
#  2   Surface area (km2)                                          229 non-null    object
#  3   Population in thousands (2017)                              229 non-null    int64
#  4   Population density (per km2, 2017)                          229 non-null    float64
#  5   Sex ratio (m per 100 f, 2017)                               229 non-null    float64
#  6   GDP: Gross domestic product (million current US$)           229 non-null    int64
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
# central tendencies
# mean --> sum/len

sum = sum(df['Population in thousands (2017)'])
length = len(df['Population in thousands (2017)'])
avg = sum/length
print(avg)
# Out:
# 32756.794759825327

# %%
df['Population in thousands (2017)'].mean()
# Out:
# 32756.794759825327

# %%
#Median --------> sort + middle index

sorted_data = df['Population in thousands (2017)'].sort_values()

# %%
# 229//2 ==114

sorted_data.reset_index()
# Out:
#      index  Population in thousands (2017)
# 0      204                               1
# 1       91                               1
# 2      149                               2
# 3       68                               3
# 4      169                               4
# ..     ...                             ...
# 224     28                          209288
# 225     96                          263991
# 226    217                          324460
# 227     95                         1339180
# 228     45                         1409517
#
# [229 rows x 2 columns]

# %%
sorted_data.iloc[114]
# Out:
# 5448

# %%
df['Population in thousands (2017)'].median()
# Out:
# 5448.0

# %%
df
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# ...

# %%
# Mode -----> most occured element

df['Region'].mode()
# Out:
# 0    Caribbean
# Name: Region, dtype: object

# %%
df['Region'].value_counts()
# Out:
# Region
# Caribbean            25
# EasternAfrica        19
# WesternAsia          18
# SouthernEurope       16
# WesternAfrica        16
# SouthAmerica         14
# NorthernEurope       13
# South-easternAsia    11
# EasternEurope        10
# SouthernAsia          9
# Polynesia             9
# MiddleAfrica          9
# WesternEurope         9
# CentralAmerica        8
# NorthernAfrica        7
# EasternAsia           7
# Micronesia            7
# SouthernAfrica        5
# NorthernAmerica       5
# Melanesia             5
# CentralAsia           5
# Oceania               2
# Name: count, dtype: int64

# %%
# Range--{min,max}

df['Population in thousands (2017)'].min()
# Out:
# 1

# %%
df['Population in thousands (2017)'].max()
# Out:
# 1409517

# %%
{1,1409517}
# Out:
# {1, 1409517}

# %%
1409517-1
# Out:
# 1409516

# %%
#Percentile
# df['Population in thousands (2017)'].percentile(0.10)
per_10 = np.percentile(df['Population in thousands (2017)'],10)
per_10
# Out:
# 54.6

# %%
q1 = np.percentile(df['Population in thousands (2017)'], 25)
q2 = np.percentile(df['Population in thousands (2017)'], 50)
q3 = np.percentile(df['Population in thousands (2017)'], 75)
print("Q1:", q1)
print("Q2:",q2)
print("Q3:", q3)
# Out:
# Q1: 431.0
# Q2: 5448.0
# Q3: 19193.0

# %%
df['Population in thousands (2017)'].quantile(0.25)
# Out:
# 431.0

# %%
df['Population in thousands (2017)'].quantile(0.50)
# Out:
# 5448.0

# %%
df['Population in thousands (2017)'].quantile(0.75)
# Out:
# 19193.0

# %%
# IQR ------> Q3-Q1

IQR = q3 - q1
IQR
# Out:
# 18762.0

# %%
LB=q1-1.5*(IQR)
UB =q3+1.5*(IQR)

# %%
LB,UB
# Out:
# (-27712.0, 47336.0)

# %%
sns.boxplot(df['Population in thousands (2017)'])
# Out:
# <Axes: ylabel='Population in thousands (2017)'>

# %%
outlier_removed=df[(df['Population in thousands (2017)']>=LB) & (df['Population in thousands (2017)'] <=UB)]

# %%
df[(df['Population in thousands (2017)']<LB)]
# Out:
# Empty DataFrame
# ...

# %%
df[(df['Population in thousands (2017)']>UB)]
# Out:
#                               country             Region Surface area (km2)  \
# 16                         Bangladesh       SouthernAsia             147570
# 28                             Brazil       SouthAmerica            8515767
# 45                              China        EasternAsia            9600000
# 46                           Colombia       SouthAmerica            1141748
# 56   Democratic Republic of the Congo       MiddleAfrica            2344858
# 62                              Egypt     NorthernAfrica            1002000
# 67                           Ethiopia      EasternAfrica            1104300
# 72                             France      WesternEurope             551500
# 78                            Germany      WesternEurope             357376
# 95                              India       SouthernAsia            3287263
# 96                          Indonesia  South-easternAsia            1910931
# ...

# %%
sns.boxplot(outlier_removed['Population in thousands (2017)'])
# Out:
# <Axes: ylabel='Population in thousands (2017)'>

# %%
df['Population in thousands (2017)'].std()
# Out:
# 133275.07991351312

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 50 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   country                                                     229 non-null    object
#  1   Region                                                      229 non-null    object
#  2   Surface area (km2)                                          229 non-null    object
#  3   Population in thousands (2017)                              229 non-null    int64
#  4   Population density (per km2, 2017)                          229 non-null    float64
#  5   Sex ratio (m per 100 f, 2017)                               229 non-null    float64
#  6   GDP: Gross domestic product (million current US$)           229 non-null    int64
# ...

# %%
col_list=[]
for col in df.columns:
    if(df[col].dtype !='object'):
        col_list.append(col)

# %%
col_list
# Out:
# ['Population in thousands (2017)',
#  'Population density (per km2, 2017)',
#  'Sex ratio (m per 100 f, 2017)',
#  'GDP: Gross domestic product (million current US$)',
#  'GDP per capita (current US$)',
#  'Economy: Industry (% of GVA)',
#  'Economy: Services and other activity (% of GVA)',
#  'Agricultural production index (2004-2006=100)',
#  'Food production index (2004-2006=100)',
#  'Urban population (% of total population)',
#  'Health: Total expenditure (% of GDP)',
#  'Seats held by women in national parliaments %',
#  'Individuals using the Internet (per 100 inhabitants)',
#  'CO2 emission estimates (million tons/tons per capita)',
#  'Energy production, primary (Petajoules)',
#  'Net Official Development Assist. received (% of GNI)']

# %%
df
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# ...

# %%
numeric_df=df[col_list]

# %%
numeric_df
# Out:
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# 1                              2930                               106.9
# 2                             41318                                17.3
# 3                                56                               278.2
# 4                                77                               163.8
# ..                              ...                                 ...
# 224                              12                                84.1
# 225                             553                                 2.1
# 226                           28250                                53.5
# 227                           17094                                23.0
# 228                           16530                                42.7
#
#      Sex ratio (m per 100 f, 2017)  \
# 0                            106.3
# ...

# %%
numeric_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 16 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Population in thousands (2017)                         229 non-null    int64
#  1   Population density (per km2, 2017)                     229 non-null    float64
#  2   Sex ratio (m per 100 f, 2017)                          229 non-null    float64
#  3   GDP: Gross domestic product (million current US$)      229 non-null    int64
#  4   GDP per capita (current US$)                           229 non-null    float64
#  5   Economy: Industry (% of GVA)                           229 non-null    float64
#  6   Economy: Services and other activity (% of GVA)        229 non-null    float64
#  7   Agricultural production index (2004-2006=100)          229 non-null    int64
# ...

# %%
correlation_mat=numeric_df.corr()
correlation_mat
# Out:
#                                                     Population in thousands (2017)  \
# Population in thousands (2017)                                            1.000000
# Population density (per km2, 2017)                                       -0.025050
# Sex ratio (m per 100 f, 2017)                                             0.016668
# GDP: Gross domestic product (million current US$)                         0.558270
# GDP per capita (current US$)                                             -0.045192
# Economy: Industry (% of GVA)                                              0.097953
# Economy: Services and other activity (% of GVA)                           0.048153
# Agricultural production index (2004-2006=100)                             0.109367
# Food production index (2004-2006=100)                                     0.107710
# Urban population (% of total population)                                 -0.057155
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation_mat,annot=True)
# Out:
# <Axes: >
